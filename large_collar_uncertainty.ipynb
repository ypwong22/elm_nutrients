# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

filename = os.path.join(os.environ['PROJDIR'], 'ELM_Phenology', 'input', 
                        'SPRUCE_CO2_CH4_FLUX_WEW_20211111.csv')

data = pd.read_csv(filename)

# %%
plt.scatter(data.loc[(data['Day or Night'] == 'Night') & (data['Year'] <= 2014), 'DOY'], 
            data.loc[(data['Day or Night'] == 'Night') & (data['Year'] <= 2014), 'CO2_flux'])

# %%
data['TS_-5'].plot()
# Out:
# <Axes: >
