# %%
""" The vmax parameter can be inversely estimated from NPP, whole-plant C:N & C:P ratios,
percentage N/P-demand satisfied by retranslocation, and growing season length """
import pandas as pd
import os

# %%
allometry = pd.DataFrame(
    [[67.52, 946.81],[73.80, 1004.90],[51.32, 832.73]], 
    index = [2, 3, 11],
    columns = ['CN','CP']
)

# %%
obs_data = pd.read_csv(os.path.join(os.environ['PROJDIR'], 'ELM_Phenology', 'output', 'extract',
                                    'extract_obs_productivity.csv'), index_col = [0,1,2])
npp = obs_data.loc['P07', ['AGNPP_Spruce','AGNPP_Tamarack','AGNPP_Shrub',
                           'ABGiomass_Spruce','AGBiomass_Tamarack','AGBiomass_Shrub']]

# %%
npp
# Out:
#            AGNPP_Spruce  AGNPP_Tamarack  AGNPP_Shrub  BGNPP_TreeShrub
# Year eCO2
# 2016 0.0            NaN             NaN          NaN          9.40000
# 2017 0.0            NaN             NaN          NaN         10.70000
# 2018 0.0            NaN             NaN          NaN         10.05000
# 2019 0.0            NaN             NaN          NaN         10.37500
# 2021 0.0            NaN             NaN          NaN         10.29375
